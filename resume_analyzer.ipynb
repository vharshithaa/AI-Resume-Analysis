# %% [markdown]
# ## Get The text from the PDF

# %%
# %pip install pdfplumber pytesseract pdf2image
# Out:
# Requirement already satisfied: pdfplumber in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (0.11.4)
# Requirement already satisfied: pytesseract in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (0.3.13)
# Requirement already satisfied: pdf2image in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (1.17.0)
# Requirement already satisfied: pdfminer.six==20231228 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (10.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from pdfplumber) (5.1.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (3.4.1)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from pdfminer.six==20231228->pdfplumber) (46.0.3)
# Requirement already satisfied: packaging>=21.3 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from pytesseract) (23.2)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfplumber
import pytesseract
from pdf2image import convert_from_path

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        # Try direct text extraction
        with pdfplumber.open(pdf_path) as pdf:
            for page in pdf.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text

        if text.strip():
            return text.strip()
    except Exception as e:
        print(f"Direct text extraction failed: {e}")

    # Fallback to OCR for image-based PDFs
    print("Falling back to OCR for image-based PDF.")
    try:
        images = convert_from_path(pdf_path)
        for image in images:
            page_text = pytesseract.image_to_string(image)
            text += page_text + "\n"
    except Exception as e:
        print(f"OCR failed: {e}")

    return text.strip()

# %%
pdf_path = "uploaded_resume.pdf"
resume_text = extract_text_from_pdf(pdf_path)

print("\nExtracted Text from PDF:")
print(resume_text)
# Out:
# Extracted Text from PDF:
# Vasala Harshitha
# Sreenidhi Institute of Science and Technology, Hyderabad
# ✆ +91 8885522063 | ✉ vasalaharshitha69@gmail.com | vasala-harshitha | vharshithaa
# Education
# Bachelor of Technology in Computer Science-DataScience CGPA : 9.32
# Sreenidhi Institute of Science and Technology, Hyderabad 2022 – 2026
# Telangana Board of Intermediate Education(TSBIE) CGPA : 9.80
# Narayana junior college, bachupally,Hyderabad 2020 – 2022
# Telangana Board of Secondary Education(SSC) CGPA : 10
# St.fransis de sales high school,korutla 2019 – 2020
# Projects
# TweetRadar| jupyter notebook,tweepy,matplotlib,seaborn and other python libraries
# ●This project performs real time sentiment analysis on tweets using NLP.
# ●This analysis helps in understanding public opinion on trending topics in real time.using NLP.
# ● code
# Body-Shape-Determination | html,css,javascript
# ● Determine a user's body shape based on their gender and specific body measurements.
# ● Suggestions for clothing styles based on the determined body shape.
# ● Live | Code
# Piggy Track | html,css,javascript with pie chart integration
# ● Help students manage their pocket money by tracking income, planned expenses, savings, and
# daily spending habits.
# ● Users can describe their savings goals,alerts users when they exceed their budget.
# ● Live | Code
# Youtube-Analysis | jupyter notebook,pandas,numpy,matplotlib and other python libraries
# ● Perform sentiment analysis on video comments using TextBlob with word clouds for positive and
# negative sentiments.
# ● Analyze emoji usage to gauge emotional responses in comments.
# ● Identify top-performing categories with box plots of maximum likes and engagement metrics like likes
# rate, dislikes rate, and comment count rate.
# ● code
# Technical Skills
# Languages : python,SQL,html,css,javascript
# Tools & Technologies : Power BI, Jupyter Notebook, Excel, pandas, matplotlib, seaborn,
# Numpy,MongoDB
# Frameworks : Bootstrap,React,Express

# %% [markdown]
# ## Set Google GenerativeAI Api Key

# %%
# %pip install google.generativeai python-dotenv
# Out:
# Requirement already satisfied: google.generativeai in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (0.8.5)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: python-dotenv in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (1.0.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (2.24.0)
# Requirement already satisfied: google-api-python-client in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (2.157.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (2.37.0)
# Requirement already satisfied: protobuf in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (4.25.8)
# Requirement already satisfied: pydantic in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (2.10.4)
# Requirement already satisfied: tqdm in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google.generativeai) (4.14.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google-ai-generativelanguage==0.6.15->google.generativeai) (1.25.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google-api-core->google.generativeai) (1.66.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google-api-core->google.generativeai) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google.generativeai) (1.67.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google.generativeai) (1.63.0rc1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google.generativeai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google.generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google.generativeai) (4.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google.generativeai) (2025.7.14)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=2.15.0->google.generativeai) (0.6.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google.generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google.generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google.generativeai) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google.generativeai) (3.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from pydantic->google.generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from pydantic->google.generativeai) (2.27.2)
# Requirement already satisfied: colorama in c:\users\vasal\appdata\local\programs\python\python312\lib\site-packages (from tqdm->google.generativeai) (0.4.6)

# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv

load_dotenv()
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
model = genai.GenerativeModel("models/gemini-2.5-flash")
# models = genai.list_models()

# for model in models:
#     print(model.name)

# %%
response = model.generate_content("What is the capital of India?")

# %%
print(response)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "The capital of India is **New Delhi**."
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 8,
#         "candidates_token_count": 9,
#         "total_token_count": 46
#       },
#       "model_version": "gemini-2.5-flash"
#     }),
# )

# %%
print(response.text)
# Out:
# The capital of India is **New Delhi**.

# %% [markdown]
# ## Resume Analysis

# %%
def analyze_resume(resume_text, job_description=None):
    if not resume_text:
        return {"error": "Resume text is required for analysis."}
    
    model = genai.GenerativeModel("models/gemini-2.5-flash")
    
    base_prompt = f"""
    You are an experienced HR with Technical Experience in the field of any one job role from Data Science, Data Analyst, DevOPS, Machine Learning Engineer, Prompt Engineer, AI Engineer, Full Stack Web Development, Big Data Engineering, Marketing Analyst, Human Resource Manager, Software Developer your task is to review the provided resume.
    Please share your professional evaluation on whether the candidate's profile aligns with the role.ALso mention Skills he already have and siggest some skills to imorve his resume , alos suggest some course he might take to improve the skills.Highlight the strengths and weaknesses.

    Resume:
    {resume_text}
    """

    if job_description:
        base_prompt += f"""
        Additionally, compare this resume to the following job description:
        
        Job Description:
        {job_description}
        
        Highlight the strengths and weaknesses of the applicant in relation to the specified job requirements.
        """

    response = model.generate_content(base_prompt)

    analysis = response.text.strip()
    return analysis

# %%
print(analyze_resume(resume_text))
# Out:
# Okay, I will review Vasala Harshitha's resume through the lens of an experienced HR professional with technical expertise, specifically focusing on the **Data Analyst** role, as her education and projects strongly align with this field.
#
# ---
#
# ### Professional Evaluation: Vasala Harshitha - Data Analyst Role
#
# **Role Alignment:**
# Vasala's profile shows **excellent alignment** for an entry-level Data Analyst role or a Data Science internship. Her academic background in "Computer Science - DataScience," coupled with relevant projects involving sentiment analysis, data manipulation, and visualization, demonstrates a strong foundational understanding and keen interest in data. The high CGPAs across all educational levels highlight a dedicated and high-achieving individual.
#
# ---
#
# **Strengths:**
#
# 1.  **Strong Academic Foundation:** A B.Tech in Computer Science - DataScience with an outstanding CGPA of 9.32 is highly impressive and indicates a solid theoretical base.
# 2.  **Relevant Project Experience:** The "TweetRadar" and "Youtube-Analysis" projects are directly applicable to data analysis roles. They showcase practical skills in:
#     *   **Natural Language Processing (NLP):** Sentiment analysis using Python libraries (TextBlob) and understanding public opinion.
#     *   **Data Extraction & Cleaning:** Implied through the use of Tweepy and processing video comments.
#     *   **Data Manipulation & Analysis:** Using pandas, NumPy.
#     *   **Data Visualization:** Matplotlib, Seaborn, word clouds, box plots for engagement metrics.
#     *   **Real-time Data Processing:** "TweetRadar" project highlights this valuable skill.
# 3.  **Proficiency in Core Tools:** Strong grasp of Python (pandas, NumPy, matplotlib, seaborn) and SQL, which are indispensable for any data-related role.
# 4.  **Exposure to Business Intelligence Tool:** Listing Power BI is a significant plus for a Data Analyst, showing an understanding of reporting and dashboarding.
# 5.  **Initiative and Practical Application:** Having four distinct projects, including some with "Live" and "Code" links, demonstrates initiative, practical coding skills, and a desire to build.
# 6.  **Web Development Basics:** While not central to a pure Data Analyst role, HTML, CSS, JavaScript, React, and Express provide a broader technical skillset, which can be useful for developing front-ends for data applications or internal tools.
#
# ---
#
# **Skills Vasala Already Possesses:**
#
# *   **Programming Languages:** Python, SQL, HTML, CSS, JavaScript
# *   **Data Manipulation & Analysis Libraries:** pandas, NumPy, Matplotlib, Seaborn, TextBlob (implied through projects)
# *   **Data Visualization Tools:** Power BI, Excel, Matplotlib, Seaborn
# *   **Development Tools:** Jupyter Notebook
# *   **Databases:** MongoDB
# *   **Web Frameworks/Libraries:** Bootstrap, React, Express
# *   **NLP Concepts:** Sentiment Analysis, Word Clouds
#
# ---
#
# **Weaknesses and Areas for Improvement / Suggested Skills:**
#
# 1.  **Depth in SQL:** While listed, the projects don't explicitly showcase complex SQL queries (e.g., advanced joins, subqueries, window functions, CTEs, stored procedures, database optimization). For a Data Analyst, deep SQL is critical for data extraction and transformation.
# 2.  **Statistical Foundations:** There's no explicit mention of statistical analysis, hypothesis testing, or A/B testing in the projects. Understanding statistical significance is paramount for drawing valid conclusions from data.
# 3.  **Data Cleaning & Preprocessing:** While implied, explicitly detailing the challenges faced and solutions implemented during data cleaning (handling missing values, outliers, inconsistent formats) would strengthen the data analysis aspect.
# 4.  **Advanced Data Visualization & Dashboarding:** While Power BI is listed, showcasing a detailed project involving interactive dashboards, key performance indicators (KPIs), and storytelling through data would be highly beneficial. Explore Tableau as well.
# 5.  **Version Control (Git/GitHub):** This is a fundamental skill for collaborative development and managing code, and it's currently missing from the "Tools & Technologies" section.
# 6.  **Cloud Platforms:** Exposure to cloud services (AWS, Azure, GCP) for data storage, warehousing (e.g., S3, Redshift, BigQuery, Snowflake), and basic ETL processes is increasingly valued.
# 7.  **Impact and Business Context:** Projects describe *what* was done but could benefit from explicitly stating the *insights* gained and their potential *business impact* or *real-world application* (e.g., "This analysis helps in understanding public opinion on trending topics in real time, enabling businesses to quickly adapt marketing strategies or address customer concerns.").
# 8.  **Project Documentation/READMEs:** Ensure the provided "code" links lead to well-documented repositories (e.g., GitHub with clear READMEs explaining methodology, results, and insights).
#
# ---
#
# **Suggested Courses / Resources to Improve Skills:**
#
# 1.  **For Advanced SQL:**
#     *   **Coursera/Udemy:** "The Complete SQL Bootcamp with PostgreSQL" (Udemy), "SQL for Data Science" (Coursera by UC Davis).
#     *   **Hackerrank/LeetCode:** Practice advanced SQL problems.
#
# 2.  **For Statistical Analysis & Hypothesis Testing:**
#     *   **Coursera:** "Statistics for Data Science with Python" (IBM), "Probability and Statistics for Data Science" (Duke University).
#     *   **Udemy:** "Statistics for Data Science and Business Analysis."
#     *   **Khan Academy:** A great free resource for foundational statistics.
#
# 3.  **For Data Cleaning & Preprocessing:**
#     *   **Kaggle:** Numerous notebooks and competitions focus on data cleaning challenges.
#     *   **DataCamp/Coursera:** "Data Cleaning in Python" courses.
#
# 4.  **For Advanced Data Visualization & Dashboarding:**
#     *   **Udemy:** "Microsoft Power BI Desktop for Business Intelligence" (advanced courses), "Tableau 2023 A-Z: Hands-On Tableau Training for Data Science."
#     *   **Official Documentation:** Microsoft Power BI community and Tableau Public for inspiration.
#
# 5.  **For Version Control (Git/GitHub):**
#     *   **Udemy:** "Git Complete: The definitive, step-by-step guide to Git."
#     *   **freeCodeCamp:** Free interactive Git and GitHub tutorials.
#     *   **GitHub Learning Lab:** Hands-on courses directly on GitHub.
#
# 6.  **For Cloud Platforms (Basics):**
#     *   **AWS Training and Certification:** "AWS Cloud Practitioner Essentials" (free).
#     *   **Azure Fundamentals (AZ-900):** Microsoft Learn modules or Udemy courses.
#     *   **GCP Cloud Digital Leader:** Google Cloud Skills Boost.
#
# 7.  **For Data Storytelling & Communication:**
#     *   **Coursera:** "Data Storytelling: Presenting Data and Information" (University of Pennsylvania).
#     *   **Books:** "Storytelling with Data" by Cole Nussbaumer Knaflic.
#
# ---
#
# **Overall Recommendation:**
#
# Vasala Harshitha has a very promising profile for an entry-level Data Analyst. Her exceptional academic record combined with hands-on projects demonstrates a strong foundation, genuine interest, and capability in the data domain. By strategically enhancing her SQL proficiency, adding statistical depth, showcasing advanced dashboarding, and incorporating version control, she will significantly strengthen her candidacy and stand out for competitive Data Analyst roles or more advanced Data Science internships. She has a solid base; now it's about adding more depth and breadth to her specialized data skills.
